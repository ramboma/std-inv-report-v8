# %%
import pandas as pd

# %%
df = pd.read_excel('../test-data/raw/answer20181012_174011233.xlsx')

# %%
df.head()
# Out:
#              学号   姓名   性别    就业年份  学校名称  学校所在省份  学校类型  学校层次  院系编号    院系名称  \
# 0           NaN  NaN  NaN     NaN   NaN     NaN   NaN   NaN   NaN     NaN
# 1  2.014046e+10  王恩赐    男  2018.0  三明学院     NaN   NaN   NaN   NaN   外国语学院
# 2  2.014166e+10  黄彦嘉    女  2018.0  三明学院     NaN   NaN   NaN   NaN    国际学院
# 3  2.014026e+10  胡丹华    男  2018.0  三明学院     NaN   NaN   NaN   NaN    旅游学院
# 4  2.014106e+10   徐磊    男  2018.0  三明学院     NaN   NaN   NaN   NaN  艺术设计学院
#
#          ...          可能的话，我会尽量避免和自己意见不同的人谈话 我喜欢拆装东西，探究其中的原理  我不喜欢交新朋友  \
# 0        ...                             NaN             NaN       NaN
# 1        ...                             NaN             NaN       NaN
# 2        ...                             NaN             NaN       NaN
# 3        ...                             NaN             NaN       NaN
# 4        ...                             NaN             NaN       NaN
#
#   给我的任务即使有充裕的时间，我也喜欢立即开始  我讨厌在完全不能确定会不会失败的情景中工作 我了解自己的能力特长  我了解自己的优点和缺点  \
# ...
